# %% [markdown]
# <h1>Поляков Данила ИУ5-63Б РК1</h1>
# <h2>Вариант №14</h2>

# %% [markdown]
# <h1>Задача №2.</h1>
# Для заданного набора данных проведите обработку пропусков в данных для одного категориального и одного количественного признака. Какие способы обработки пропусков в данных для категориальных и количественных признаков Вы использовали? Какие признаки Вы будете использовать для дальнейшего построения моделей машинного обучения и почему?

# %% [markdown]
# <h1>Датасет 6</h1>
# https://www.kaggle.com/datasets/mohansacharya/graduate-admissions

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="ticks")

# %%
data = pd.read_csv('Admission_Predict_Ver1.1.csv', sep=",")

# %%
data.dtypes
# Out:
# Serial No.             int64
# GRE Score            float64
# TOEFL Score            int64
# University Rating    float64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %% [markdown]
# <h3>Находим пропуски</h3>

# %%
# проверим есть ли пропущенные значения
data.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            28
# TOEFL Score           0
# University Rating    14
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1      337.0          118                4.0  4.5   4.5  9.65
# 1           2      324.0          107                4.0  4.0   4.5  8.87
# 2           3      316.0          104                3.0  3.0   3.5  8.00
# 3           4      322.0          110                3.0  3.5   2.5  8.67
# 4           5      314.0          103                NaN  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 500

# %% [markdown]
# <h3>Вычислим процент пропусков для двух признаков</h3>

# %%
# Выберем числовые колонки с пропущенными значениями
num_cols = []

# Цикл по колонкам датасета
for col in data.columns:
    # Проверим, содержит ли столбец пропущенные значения
    if data[col].isnull().any():
        # Проверим, является ли тип данных столбца числовым
        if data[col].dtype in ['float64', 'object']:
            num_cols.append(col)
            # Выведем информацию о столбце
            temp_null_count = data[data[col].isnull()].shape[0]
            temp_perc = round((temp_null_count / data.shape[0]) * 100.0, 2)
            print('Колонка {}. Тип данных {}. Количество пустых значений {}, {}%.'.format(col, data[col].dtype, temp_null_count, temp_perc))
# Out:
# Колонка GRE Score. Тип данных float64. Количество пустых значений 28, 5.6%.
# Колонка University Rating. Тип данных float64. Количество пустых значений 14, 2.8%.

# %%
data_num = data[num_cols]
data_num
# Out:
#      GRE Score  University Rating
# 0        337.0                4.0
# 1        324.0                4.0
# 2        316.0                3.0
# 3        322.0                3.0
# 4        314.0                NaN
# ..         ...                ...
# 495      332.0                NaN
# 496      337.0                5.0
# 497      330.0                5.0
# 498        NaN                4.0
# 499      327.0                4.0
#
# [500 rows x 2 columns]

# %%
data_num_GRE = data_num[['GRE Score']]
data_num_GRE.head()
# Out:
#    GRE Score
# 0      337.0
# 1      324.0
# 2      316.0
# 3      322.0
# 4      314.0

# %%
data_num_Rating = data_num[['University Rating']]
data_num_Rating.head()
# Out:
#    University Rating
# 0                4.0
# 1                4.0
# 2                3.0
# 3                3.0
# 4                NaN

# %% [markdown]
# <h3>Заполним пропуски двумя разными способами</h3>

# %%
from sklearn.impute import SimpleImputer
from sklearn.impute import MissingIndicator

# %%
GRE_data = data[['GRE Score']]
GRE_data.head()
# Out:
#    GRE Score
# 0      337.0
# 1      324.0
# 2      316.0
# 3      322.0
# 4      314.0

# %%
GRE_data['GRE Score'].unique()
# Out:
# array([337., 324., 316., 322., 314., 330., 321., 308., 302., 323., 325.,
#         nan, 328., 307., 311., 317., 319., 318., 303., 312., 334., 336.,
#        340., 298., 295., 310., 300., 327., 338., 331., 320., 299., 304.,
#        313., 332., 326., 329., 339., 309., 315., 301., 296., 294., 290.,
#        335., 333., 306., 297., 293., 305.])

# %% [markdown]
# Видим значение nan

# %% [markdown]
# <h3>Заполним наиболее частыми значениями</h3>

# %%
# Импьютация наиболее частыми значениями
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
data_imp = imp.fit_transform(GRE_data)
data_imp
# Out:
# array([[337.],
#        [324.],
#        [316.],
#        [322.],
#        [314.],
#        [330.],
#        [321.],
#        [308.],
#        [302.],
#        [323.],
#        [325.],
#        [312.],
#        [328.],
#        [307.],
#        [311.],
#        [314.],
#        [317.],
#        [319.],
#        [318.],
#        [303.],
#        [312.],
#        [325.],
#        [312.],
#        [334.],
#        [336.],
#        [340.],
#        [322.],
#        [298.],
#        [295.],
#        [310.],
#        [300.],
#        [327.],
#        [338.],
#        [340.],
#        [331.],
#        [320.],
#        [299.],
#        [300.],
#        [304.],
#        [307.],
#        [308.],
#        [316.],
#        [313.],
#        [332.],
#        [326.],
#        [322.],
#        [329.],
#        [339.],
#        [321.],
#        [327.],
#        [313.],
#        [312.],
#        [334.],
#        [324.],
#        [322.],
#        [320.],
#        [312.],
#        [298.],
#        [300.],
#        [311.],
#        [309.],
#        [307.],
#        [304.],
#        [315.],
#        [325.],
#        [325.],
#        [327.],
#        [316.],
#        [318.],
#        [328.],
#        [332.],
#        [336.],
#        [321.],
#        [314.],
#        [314.],
#        [329.],
#        [327.],
#        [301.],
#        [296.],
#        [294.],
#        [312.],
#        [340.],
#        [320.],
#        [322.],
#        [340.],
#        [319.],
#        [315.],
#        [317.],
#        [312.],
#        [316.],
#        [318.],
#        [299.],
#        [298.],
#        [301.],
#        [303.],
#        [304.],
#        [312.],
#        [331.],
#        [332.],
#        [323.],
#        [322.],
#        [312.],
#        [314.],
#        [317.],
#        [326.],
#        [316.],
#        [329.],
#        [338.],
#        [331.],
#        [304.],
#        [312.],
#        [321.],
#        [301.],
#        [320.],
#        [311.],
#        [310.],
#        [312.],
#        [290.],
#        [296.],
#        [327.],
#        [335.],
#        [334.],
#        [310.],
#        [308.],
#        [301.],
#        [300.],
#        [323.],
#        [319.],
#        [326.],
#        [333.],
#        [339.],
#        [303.],
#        [309.],
#        [323.],
#        [333.],
#        [314.],
#        [312.],
#        [316.],
#        [326.],
#        [318.],
#        [329.],
#        [312.],
#        [331.],
#        [340.],
#        [325.],
#        [320.],
#        [315.],
#        [326.],
#        [339.],
#        [311.],
#        [334.],
#        [332.],
#        [321.],
#        [324.],
#        [326.],
#        [312.],
#        [315.],
#        [309.],
#        [306.],
#        [297.],
#        [315.],
#        [298.],
#        [318.],
#        [317.],
#        [329.],
#        [322.],
#        [302.],
#        [312.],
#        [293.],
#        [311.],
#        [312.],
#        [334.],
#        [322.],
#        [323.],
#        [321.],
#        [320.],
#        [329.],
#        [319.],
#        [309.],
#        [307.],
#        [300.],
#        [305.],
#        [299.],
#        [312.],
#        [316.],
#        [327.],
#        [317.],
#        [335.],
#        [331.],
#        [324.],
#        [324.],
#        [323.],
#        [322.],
#        [336.],
#        [316.],
#        [307.],
#        [306.],
#        [310.],
#        [311.],
#        [313.],
#        [317.],
#        [315.],
#        [312.],
#        [334.],
#        [298.],
#        [295.],
#        [315.],
#        [310.],
#        [305.],
#        [301.],
#        [325.],
#        [328.],
#        [338.],
#        [333.],
#        [331.],
#        [330.],
#        [322.],
#        [321.],
#        [324.],
#        [312.],
#        [313.],
#        [316.],
#        [324.],
#        [308.],
#        [312.],
#        [296.],
#        [306.],
#        [312.],
#        [318.],
#        [324.],
#        [313.],
#        [319.],
#        [312.],
#        [304.],
#        [330.],
#        [312.],
#        [325.],
#        [329.],
#        [310.],
#        [299.],
#        [296.],
#        [317.],
#        [324.],
#        [325.],
#        [314.],
#        [328.],
#        [316.],
#        [311.],
#        [324.],
#        [321.],
#        [320.],
#        [316.],
#        [318.],
#        [335.],
#        [321.],
#        [307.],
#        [309.],
#        [324.],
#        [326.],
#        [331.],
#        [327.],
#        [312.],
#        [308.],
#        [324.],
#        [325.],
#        [313.],
#        [312.],
#        [314.],
#        [327.],
#        [308.],
#        [306.],
#        [299.],
#        [312.],
#        [312.],
#        [315.],
#        [322.],
#        [329.],
#        [320.],
#        [308.],
#        [304.],
#        [311.],
#        [317.],
#        [312.],
#        [321.],
#        [340.],
#        [331.],
#        [336.],
#        [324.],
#        [312.],
#        [313.],
#        [307.],
#        [300.],
#        [302.],
#        [312.],
#        [316.],
#        [317.],
#        [310.],
#        [320.],
#        [330.],
#        [305.],
#        [309.],
#        [312.],
#        [322.],
#        [323.],
#        [313.],
#        [321.],
#        [323.],
#        [325.],
#        [312.],
#        [308.],
#        [320.],
#        [312.],
#        [311.],
#        [301.],
#        [305.],
#        [308.],
#        [312.],
#        [300.],
#        [324.],
#        [327.],
#        [317.],
#        [323.],
#        [314.],
#        [305.],
#        [315.],
#        [326.],
#        [299.],
#        [312.],
#        [324.],
#        [297.],
#        [327.],
#        [311.],
#        [308.],
#        [319.],
#        [312.],
#        [325.],
#        [319.],
#        [332.],
#        [323.],
#        [324.],
#        [312.],
#        [326.],
#        [308.],
#        [305.],
#        [295.],
#        [316.],
#        [304.],
#        [299.],
#        [302.],
#        [313.],
#        [318.],
#        [325.],
#        [303.],
#        [300.],
#        [297.],
#        [317.],
#        [327.],
#        [312.],
#        [314.],
#        [321.],
#        [322.],
#        [334.],
#        [338.],
#        [306.],
#        [313.],
#        [330.],
#        [320.],
#        [311.],
#        [298.],
#        [301.],
#        [310.],
#        [324.],
#        [336.],
#        [312.],
#        [315.],
#        [304.],
#        [297.],
#        [290.],
#        [303.],
#        [311.],
#        [322.],
#        [319.],
#        [324.],
#        [300.],
#        [340.],
#        [335.],
#        [302.],
#        [307.],
#        [296.],
#        [320.],
#        [314.],
#        [318.],
#        [326.],
#        [317.],
#        [329.],
#        [312.],
#        [325.],
#        [330.],
#        [312.],
#        [333.],
#        [304.],
#        [315.],
#        [324.],
#        [330.],
#        [311.],
#        [302.],
#        [322.],
#        [298.],
#        [297.],
#        [300.],
#        [301.],
#        [312.],
#        [314.],
#        [317.],
#        [321.],
#        [327.],
#        [315.],
#        [316.],
#        [309.],
#        [308.],
#        [299.],
#        [321.],
#        [322.],
#        [334.],
#        [325.],
#        [323.],
#        [312.],
#        [310.],
#        [316.],
#        [340.],
#        [312.],
#        [320.],
#        [324.],
#        [316.],
#        [306.],
#        [309.],
#        [310.],
#        [317.],
#        [318.],
#        [312.],
#        [305.],
#        [332.],
#        [331.],
#        [321.],
#        [324.],
#        [328.],
#        [327.],
#        [320.],
#        [312.],
#        [315.],
#        [320.],
#        [324.],
#        [328.],
#        [319.],
#        [310.],
#        [305.],
#        [299.],
#        [312.],
#        [312.],
#        [329.],
#        [319.],
#        [301.],
#        [307.],
#        [304.],
#        [298.],
#        [305.],
#        [314.],
#        [318.],
#        [323.],
#        [326.],
#        [320.],
#        [311.],
#        [327.],
#        [316.],
#        [308.],
#        [300.],
#        [304.],
#        [309.],
#        [318.],
#        [325.],
#        [321.],
#        [312.],
#        [328.],
#        [304.],
#        [317.],
#        [311.],
#        [319.],
#        [327.],
#        [322.],
#        [302.],
#        [307.],
#        [297.],
#        [298.],
#        [300.],
#        [301.],
#        [332.],
#        [337.],
#        [330.],
#        [312.],
#        [327.]])

# %%
# Пустые значения отсутствуют
np.unique(data_imp)
# Out:
# array([290., 293., 294., 295., 296., 297., 298., 299., 300., 301., 302.,
#        303., 304., 305., 306., 307., 308., 309., 310., 311., 312., 313.,
#        314., 315., 316., 317., 318., 319., 320., 321., 322., 323., 324.,
#        325., 326., 327., 328., 329., 330., 331., 332., 333., 334., 335.,
#        336., 337., 338., 339., 340.])

# %% [markdown]
# Значение nan исчезло => пропусков нет

# %% [markdown]
# <h3>Выполним для категориального признака</h3>

# %%
Rating_data = data[['University Rating']]
Rating_data.head()
# Out:
#    University Rating
# 0                4.0
# 1                4.0
# 2                3.0
# 3                3.0
# 4                NaN

# %%
np.unique(Rating_data)
# Out:
# array([ 1.,  2.,  3.,  4.,  5., nan])

# %% [markdown]
# <h3>Заполним пропуски константой</h3>

# %%
# Импьютация константой
imp1 = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=3)
data_imp1 = imp1.fit_transform(Rating_data)
data_imp1
# Out:
# array([[4.],
#        [4.],
#        [3.],
#        [3.],
#        [3.],
#        [5.],
#        [3.],
#        [2.],
#        [1.],
#        [3.],
#        [3.],
#        [4.],
#        [4.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [3.],
#        [4.],
#        [5.],
#        [5.],
#        [3.],
#        [2.],
#        [1.],
#        [1.],
#        [2.],
#        [3.],
#        [2.],
#        [2.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [3.],
#        [3.],
#        [4.],
#        [3.],
#        [2.],
#        [4.],
#        [4.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [3.],
#        [2.],
#        [2.],
#        [3.],
#        [4.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [3.],
#        [2.],
#        [3.],
#        [2.],
#        [2.],
#        [1.],
#        [3.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [2.],
#        [3.],
#        [2.],
#        [2.],
#        [3.],
#        [4.],
#        [2.],
#        [3.],
#        [4.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [4.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [3.],
#        [4.],
#        [2.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [3.],
#        [4.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [3.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [5.],
#        [4.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [4.],
#        [2.],
#        [4.],
#        [5.],
#        [5.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [3.],
#        [3.],
#        [4.],
#        [5.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [5.],
#        [4.],
#        [4.],
#        [4.],
#        [4.],
#        [4.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [4.],
#        [3.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [5.],
#        [5.],
#        [3.],
#        [2.],
#        [2.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [4.],
#        [4.],
#        [5.],
#        [4.],
#        [5.],
#        [4.],
#        [4.],
#        [4.],
#        [3.],
#        [3.],
#        [3.],
#        [4.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [3.],
#        [4.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [5.],
#        [5.],
#        [4.],
#        [5.],
#        [3.],
#        [1.],
#        [1.],
#        [2.],
#        [3.],
#        [3.],
#        [2.],
#        [4.],
#        [3.],
#        [2.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [4.],
#        [4.],
#        [4.],
#        [3.],
#        [3.],
#        [4.],
#        [4.],
#        [5.],
#        [3.],
#        [2.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [4.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [3.],
#        [5.],
#        [2.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [3.],
#        [2.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [3.],
#        [2.],
#        [3.],
#        [3.],
#        [4.],
#        [3.],
#        [4.],
#        [3.],
#        [4.],
#        [4.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [3.],
#        [4.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [4.],
#        [2.],
#        [3.],
#        [2.],
#        [3.],
#        [3.],
#        [4.],
#        [4.],
#        [3.],
#        [5.],
#        [5.],
#        [5.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [1.],
#        [3.],
#        [3.],
#        [3.],
#        [2.],
#        [3.],
#        [2.],
#        [2.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [3.],
#        [4.],
#        [5.],
#        [2.],
#        [3.],
#        [4.],
#        [3.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [3.],
#        [2.],
#        [3.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [3.],
#        [3.],
#        [4.],
#        [3.],
#        [4.],
#        [5.],
#        [2.],
#        [2.],
#        [2.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [2.],
#        [4.],
#        [3.],
#        [3.],
#        [4.],
#        [3.],
#        [4.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [3.],
#        [3.],
#        [4.],
#        [3.],
#        [3.],
#        [1.],
#        [1.],
#        [2.],
#        [4.],
#        [3.],
#        [4.],
#        [4.],
#        [3.],
#        [3.],
#        [2.],
#        [2.],
#        [3.],
#        [3.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [3.],
#        [3.],
#        [2.],
#        [5.],
#        [3.],
#        [2.],
#        [4.],
#        [4.],
#        [3.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [1.],
#        [4.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [4.],
#        [4.],
#        [3.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [4.],
#        [4.],
#        [3.],
#        [4.],
#        [3.],
#        [2.],
#        [4.],
#        [4.],
#        [3.],
#        [4.],
#        [4.],
#        [5.],
#        [3.],
#        [4.],
#        [2.],
#        [4.],
#        [3.],
#        [3.],
#        [4.],
#        [3.],
#        [4.],
#        [3.],
#        [4.],
#        [3.],
#        [5.],
#        [3.],
#        [2.],
#        [3.],
#        [4.],
#        [3.],
#        [3.],
#        [2.],
#        [4.],
#        [4.],
#        [2.],
#        [3.],
#        [3.],
#        [5.],
#        [5.],
#        [4.],
#        [4.]])

# %%
np.unique(data_imp1)
# Out:
# array([1., 2., 3., 4., 5.])

# %% [markdown]
# Пропусков нет

# %%
data.head(20)
# Out:
#     Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0            1      337.0          118                4.0  4.5   4.5  9.65
# 1            2      324.0          107                4.0  4.0   4.5  8.87
# 2            3      316.0          104                3.0  3.0   3.5  8.00
# 3            4      322.0          110                3.0  3.5   2.5  8.67
# 4            5      314.0          103                NaN  2.0   3.0  8.21
# 5            6      330.0          115                5.0  4.5   3.0  9.34
# 6            7      321.0          109                3.0  3.0   4.0  8.20
# 7            8      308.0          101                2.0  3.0   4.0  7.90
# 8            9      302.0          102                1.0  2.0   1.5  8.00
# 9           10      323.0          108                3.0  3.5   3.0  8.60
# 10          11      325.0          106                3.0  3.5   4.0  8.40
# 11          12        NaN          111                4.0  4.0   4.5  9.00
# 12          13      328.0          112                4.0  4.0   4.5  9.10
# 13          14      307.0          109                3.0  4.0   3.0  8.00
# 14          15      311.0          104                3.0  3.5   2.0  8.20
# 15          16      314.0          105                3.0  3.5   2.5  8.30
# 16          17      317.0          107                3.0  4.0   3.0  8.70
# 17          18      319.0          106                3.0  4.0   3.0  8.00
# 18          19      318.0          110                3.0  4.0   3.0  8.80
# 19          20      303.0          102                3.0  3.5   3.0  8.50
#
#     Research  Chance of Admit
# 0          1              0.92
# 1          1              0.76
# 2          1              0.72
# 3          1              0.80
# 4          0              0.65
# 5          1              0.90
# 6          1              0.75
# 7          0              0.68
# 8          0              0.50
# 9          0              0.45
# 10         1              0.52
# 11         1              0.84
# 12         1              0.78
# 13         1              0.62
# 14         1              0.61
# 15         0              0.54
# 16         0              0.66
# 17         1              0.65
# 18         0              0.63
# 19         0              0.62

# %% [markdown]
# <h1>График "Ящик с усами (boxplot)" для колонки "TOEFL Score"</h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Построение графика
sns.boxplot(data=data, x = "TOEFL Score")

# Отображение графика
plt.show()
